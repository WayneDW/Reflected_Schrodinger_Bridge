# %%
import autograd.numpy as np
from autograd import grad
from autograd.numpy import log, sqrt, sin, cos, exp, pi, prod
from autograd.numpy.random import normal, uniform

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
import scipy.stats
from tqdm import tqdm

# %%
from tools import Helper, Sampler
from domain import Flower, Polygon, Heart, Cross, Star

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
np.random.seed(9)

# %%
def plot_domain(myDomainClass):
    points = myDomainClass.position(np.arange(0, 1, 0.001))
    fig = plt.figure(figsize=(3, 3))
    plt.plot(points[0, :], points[1, :])
    plt.legend(loc="upper left", prop={'size': 10})
    plt.tight_layout()
    plt.show()

# %%
def plot_MCMC_traj(myHelper, iters=1e5, lr=1e-4, boundary_=1.5):
    sampler = Sampler(myHelper, boundary=boundary_, xinit=[0.,0.], lr=lr, T=2)
    for iters in tqdm(range(int(iters))):
        sampler.rgld_step(iters)
        if iters % 50000 == 50000-1:
            fig = plt.figure(figsize=(4, 4))
            plt.plot(sampler.list[0, :], sampler.list[1, :], \
                     linewidth=0.3, marker='.', markersize=3, color='r', label="Iteration="+str(iters)) 
            plt.legend(loc="upper left", prop={'size': 10})
            plt.xlim([-boundary_, boundary_])
            plt.ylim([-boundary_, boundary_])
            plt.tight_layout()
            plt.show()

# %%
myFlower = Flower(petals=5, move_out=3)
plot_domain(myFlower)
# Out:
# No handles with labels found to put in legend.

# %%
myHelper = Helper(Flower, grid_radius=1e-2, grid_curve=1e-3)

# %%
plot_MCMC_traj(myHelper, iters=3e5, boundary_=1.5)
# Out:
#  17%|█▋        | 49990/300000 [01:52<07:09, 582.46it/s]
#  33%|███▎      | 99953/300000 [03:45<11:20, 293.84it/s]
#  50%|████▉     | 149938/300000 [05:37<05:41, 439.13it/s]
#  67%|██████▋   | 199977/300000 [07:28<03:25, 487.57it/s]
#  83%|████████▎ | 249998/300000 [08:22<01:30, 552.68it/s]
# 100%|█████████▉| 299980/300000 [09:20<00:00, 855.50it/s]
# 100%|██████████| 300000/300000 [09:20<00:00, 535.48it/s]

# %%
myHeart = Heart()
plot_domain(myHeart)
# Out:
# No handles with labels found to put in legend.

# %%
myHelper = Helper(Heart, grid_radius=1e-2, grid_curve=1e-3)

# %%
plot_MCMC_traj(myHelper, iters=3e5, boundary_=2)
# Out:
#  17%|█▋        | 49955/300000 [00:46<02:42, 1535.71it/s]
#  33%|███▎      | 99931/300000 [01:30<02:16, 1462.87it/s]
#  50%|████▉     | 149992/300000 [03:10<03:33, 703.25it/s]
#  67%|██████▋   | 199950/300000 [04:46<03:23, 491.62it/s]
#  83%|████████▎ | 249993/300000 [06:22<01:08, 725.84it/s]
# 100%|█████████▉| 299969/300000 [07:52<00:00, 655.73it/s]
# 100%|██████████| 300000/300000 [07:52<00:00, 634.79it/s]

# %%
myPolygon = Polygon(corners=8)
plot_domain(myPolygon)
# Out:
# No handles with labels found to put in legend.

# %%
myHelper = Helper(Polygon)

# %%
plot_MCMC_traj(myHelper, iters=3e5, lr=3e-4, boundary_=2)
# Out:
#  17%|█▋        | 49940/300000 [00:54<06:47, 613.37it/s]
#  33%|███▎      | 99905/300000 [01:49<03:24, 979.33it/s]
#  50%|████▉     | 149964/300000 [02:46<02:51, 873.08it/s]
#  67%|██████▋   | 199918/300000 [03:42<02:08, 777.41it/s]
#  83%|████████▎ | 249994/300000 [04:37<01:12, 688.31it/s]
# 100%|█████████▉| 299986/300000 [05:37<00:00, 1300.34it/s]
# 100%|██████████| 300000/300000 [05:37<00:00, 888.40it/s]

# %%
myStar = Star()
plot_domain(myStar)
# Out:
# No handles with labels found to put in legend.

# %%
myHelper = Helper(Star, grid_radius=1e-2, grid_curve=1e-3)

# %%
plot_MCMC_traj(myHelper, iters=3e5, lr=3e-4, boundary_=1.5)
# Out:
#  17%|█▋        | 49983/300000 [01:37<11:05, 375.51it/s]
#  33%|███▎      | 99972/300000 [03:13<08:09, 408.76it/s]
#  50%|████▉     | 149922/300000 [04:53<06:40, 375.13it/s]
#  67%|██████▋   | 199945/300000 [06:30<02:26, 681.57it/s]
#  83%|████████▎ | 249968/300000 [08:14<01:56, 430.81it/s]
# 100%|█████████▉| 299986/300000 [09:57<00:00, 592.28it/s]
# 100%|██████████| 300000/300000 [09:58<00:00, 501.60it/s]

# %%
myCross = Cross()
plot_domain(myCross)
# Out:
# No handles with labels found to put in legend.

# %%
myHelper = Helper(Cross, grid_radius=3e-3, grid_curve=3e-4)

# %%
plot_MCMC_traj(myHelper, iters=3e5, lr=3e-4, boundary_=1.5)
# Out:
#   3%|▎         | 10342/300000 [05:04<2:02:49, 39.31it/s]
